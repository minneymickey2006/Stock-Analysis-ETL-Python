# %%
import pandas as pd
import requests

# %%
ticker = "AAPL"
iex_api_key = 'pk_ac8134c93c6f4fc588f5c48386e9c1ba'
api_url = f'https://cloud.iexapis.com/stable/stock/{ticker}/intraday-prices?token={iex_api_key}'
df = requests.get(api_url).json()
type(df)
pd.DataFrame(df)
# Out:
#                                                      0
# 0    b'[{"date":"2023-02-02","minute":"09:30","labe...
# 1    b'069,"volume":30600,"notional":4561515.5,"num...
# 2    b'9.42,"low":148.83,"open":149.26,"close":148....
# 3    b'"2023-02-02","minute":"09:32","label":"09:32...
# 4    b'otional":null,"numberOfTrades":null},{"date"...
# ..                                                 ...
# 552  b'ume":null,"notional":null,"numberOfTrades":n...
# 553  b',"open":null,"close":null,"average":null,"vo...
# 554  b'59","label":"03:59 PM","high":null,"low":nul...
# 555  b'des":null},{"date":"2023-02-02","minute":"16...
# 556  b'll,"volume":null,"notional":null,"numberOfTr...
#
# [557 rows x 1 columns]

# %%
# Out:
#     close    high     low   open   priceDate symbol     volume  \
# 0  150.82  151.18  148.17  148.9  2023-02-02   AAPL  118338980
#
#                   id   key subkey  ...    uLow    uVolume  fOpen  fClose  \
# 0  HISTORICAL_PRICES  AAPL         ...  148.17  118338980  148.9  150.82
#
#     fHigh    fLow    fVolume      label  change  changePercent
# 0  151.18  148.17  118338980  Feb 2, 23       0              0
#
# [1 rows x 27 columns]

# %%
ticker = "AAPL"
iex_api_key = 'pk_ac8134c93c6f4fc588f5c48386e9c1ba'
api_url = f'https://cloud.iexapis.com/stable/stock/{ticker}/quote?token={iex_api_key}'
df = requests.get(api_url).json()

# %%
type(df)
# Out:
# dict

# %%
pd.DataFrame([df])
# Out:
#    avgTotalVolume calculationPrice  change  changePercent close closeSource  \
# 0        70459944             tops    4.45         0.0306  None    official
#
#   closeTime companyName currency delayedPrice  ... peRatio previousClose  \
# 0      None   Apple Inc      USD         None  ...   24.53        145.43
#
#   previousVolume primaryExchange symbol volume week52High week52Low  \
# 0       77663633          NASDAQ   AAPL   None     178.58    124.17
#
#    ytdChange  isUSMarketOpen
# 0   0.149895            True
#
# [1 rows x 56 columns]

# %%
attributes = ['symbol','latestPrice','marketCap','peRatio']
for i in attributes:
    print(df[i])
# Out:
# AAPL
# 149.91
# 2374006690830
# 24.54

# %%
ticker = "AAPL"
iex_api_key = 'pk_ac8134c93c6f4fc588f5c48386e9c1ba'
api_url = f'https://cloud.iexapis.com/stable/stock/{ticker}/chart/max?token={iex_api_key}'
df = requests.get(api_url).json()
print(df)
# Out:
# [{'close': 3.03, 'high': 3.05, 'low': 2.9771, 'open': 2.9984, 'priceDate': '2006-12-29', 'symbol': 'AAPL', 'volume': 1077284571.999999, 'id': 'HISTORICAL_PRICES', 'key': 'AAPL', 'subkey': '', 'date': '2006-12-29', 'updated': 1672438981000, 'changeOverTime': 0, 'marketChangeOverTime': 0, 'uOpen': 83.955, 'uClose': 84.84, 'uHigh': 85.4, 'uLow': 83.36, 'uVolume': 38474449, 'fOpen': 2.5527, 'fClose': 2.5796, 'fHigh': 2.5966, 'fLow': 2.5346, 'fVolume': 1077284571.999999, 'label': 'Dec 29, 06', 'change': 0, 'changePercent': 0}, {'close': 2.9929, 'high': 3.0921, 'low': 2.925, 'open': 3.03, 'priceDate': '2007-01-03', 'symbol': 'AAPL', 'volume': 1245732991.9999988, 'id': 'HISTORICAL_PRICES', 'key': 'AAPL', 'subkey': '', 'date': '
 'id': 'HISTORICAL_PRICES', 'key': 'AAPL', 'subkey': '', 'date': '2007-01-10', 'updated': 1672438983000, 'changeOverTime': 0.14333333333333345, 'marketChangeOverTime': 0.14333333333333345, 'uOpen': 93.0091, 'uClose': 97, 'uHigh': 97.8, 'uLow': 93.45, 'uVolume': 105657993, 'fOpen': 2.828, 'fClose': 2.9493, 'fHigh': 2.9736, 'fLow': 2.8414, 'fVolume': 2958423803.999997, 'label': 'Jan  ...

# %%
type(df)
pd.DataFrame(df)
# Out:
#          close      high       low      open   priceDate symbol        volume  \
# 0       3.0300    3.0500    2.9771    2.9984  2006-12-29   AAPL  1.077285e+09
# 1       2.9929    3.0921    2.9250    3.0300  2007-01-03   AAPL  1.245733e+09
# 2       3.0593    3.0696    2.9936    2.9914  2007-01-04   AAPL  8.561265e+08
# 3       3.0375    3.0786    3.0143    3.0632  2007-01-05   AAPL  8.354034e+08
# 4       3.0525    3.0904    3.0457    3.0700  2007-01-08   AAPL  7.977253e+08
# ...        ...       ...       ...       ...         ...    ...           ...
# 4052  145.9300  147.2300  143.0800  143.1550  2023-01-27   AAPL  7.055584e+07
# 4053  143.0000  145.5500  142.8500  144.9550  2023-01-30   AAPL  6.401527e+07
# 4054  144.2900  144.3400  142.2800  142.7000  2023-01-31   AAPL  6.587446e+07
# 4055  145.4300  146.6100  141.3200  143.9700  2023-02-01   AAPL  7.766363e+07
# 4056  150.8200  151.1800  148.1700  148.9000  2023-02-02   AAPL  1.183390e+08
#
#                      id   key subkey  ...    uLow    uVolume     fOpen  \
# 0     HISTORICAL_PRICES  AAPL         ...   83.36   38474449    2.5527
# 1     HISTORICAL_PRICES  AAPL         ...   81.90   44490464    2.5796
# 2     HISTORICAL_PRICES  AAPL         ...   83.82   30575948    2.5467
# 3     HISTORICAL_PRICES  AAPL         ...   84.40   29835835    2.6079
# 4     HISTORICAL_PRICES  AAPL         ...   85.28   28490191    2.6136
# ...                 ...   ...    ...  ...     ...        ...       ...
# 4052  HISTORICAL_PRICES  AAPL         ...  143.08   70555843  143.1550
# 4053  HISTORICAL_PRICES  AAPL         ...  142.85   64015274  144.9550
# 4054  HISTORICAL_PRICES  AAPL         ...  142.28   65874459  142.7000
# 4055  HISTORICAL_PRICES  AAPL         ...  141.32   77663633  143.9700
# 4056  HISTORICAL_PRICES  AAPL         ...  148.17  118338980  148.9000
#
#         fClose     fHigh      fLow       fVolume       label  change  \
# 0       2.5796    2.5966    2.5346  1.077285e+09  Dec 29, 06  0.0000
# 1       2.5480    2.6325    2.4902  1.245733e+09   Jan 3, 07 -0.0371
# 2       2.6045    2.6133    2.5486  8.561265e+08   Jan 4, 07  0.0664
# 3       2.5860    2.6209    2.5662  8.354034e+08   Jan 5, 07 -0.0218
# 4       2.5987    2.6310    2.5930  7.977253e+08   Jan 8, 07  0.0150
# ...        ...       ...       ...           ...         ...     ...
# 4052  145.9300  147.2300  143.0800  7.055584e+07  Jan 27, 23  1.9700
# 4053  143.0000  145.5500  142.8500  6.401527e+07  Jan 30, 23 -2.9300
# 4054  144.2900  144.3400  142.2800  6.587446e+07  Jan 31, 23  1.2900
# 4055  145.4300  146.6100  141.3200  7.766363e+07   Feb 1, 23  1.1400
# 4056  150.8200  151.1800  148.1700  1.183390e+08   Feb 2, 23  5.3900
#
#       changePercent
# 0            0.0000
# 1           -0.0122
# 2            0.0222
# 3           -0.0071
# 4            0.0049
# ...             ...
# 4052         0.0137
# 4053        -0.0201
# 4054         0.0090
# 4055         0.0079
# 4056         0.0371
#
# [4057 rows x 27 columns]
